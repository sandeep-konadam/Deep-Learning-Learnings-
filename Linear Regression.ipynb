# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes

# %%
data = load_diabetes()
data['feature_names']
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
data['target']
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...

# %%
x= data.data[:,np.newaxis,2]
y=data.target

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (353, 1)

# %%
X_test.shape , y_train.shape, y_test.shape
# Out:
# ((89, 1), (353,), (89,))

# %%
X_test

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([145.80622687, 188.85739048, 147.95878505, 203.92529774,
#        131.8145987 , 127.50948234, 322.31599764, 197.4676232 ,
#         61.85645785, 167.33180868, 118.89924962,  94.14483055,
#         90.91599328, 166.25552959,  96.29738873, 157.64529687,
#        223.29832136, 240.5187868 , 180.24715776, 210.38297228,
#        191.00994866, 109.21273781, 102.75506327, 174.86576231,
#        196.39134411, 166.25552959, 211.45925137, 133.96715688,
#         78.0006442 , 130.73831961, 244.82390316, 114.59413326,
#        166.25552959, 145.80622687, 192.08622775, 229.7559959 ,
#        121.0518078 , 118.89924962, 121.0518078 ,  94.14483055,
#         82.30576056, 122.12808689, 129.66204052, 118.89924962,
#        107.06017963, 116.74669144, 115.67041235, 101.67878418,
#         67.2378533 , 153.34018051, 210.38297228,  82.30576056,
#        169.48436686, 111.36529599, 133.96715688, 216.84064682,
#        105.98390054, 213.61180955, 133.96715688,  97.37366782,
# ...

# %%
plt.scatter(X_test, y_test, color='black')
plt.plot(X_test, y_pred, color='blue', linewidth=3)
plt.title('Linear Regression on Diabetes Dataset')
plt.xlabel('Feature')
plt.ylabel('Target')
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
Data=load_iris()
a=Data.data
b=(Data.target==2).astype(int)

# %%
A_train, A_test, b_train, b_test = train_test_split(a, b, test_size=0.2, random_state=42)

# %%
model1=LogisticRegression()

# %%
model1.fit(A_train,b_train)
# Out:
# LogisticRegression()

# %%
a_pred=model1.predict(A_test)

# %%
accuracy=accuracy_score(a_pred,b_test)
confusionmatrix=confusion_matrix(a_pred,b_test)
report=classification_report(a_pred,b_test)

# %%
print(accuracy)
# Out:
# 1.0

# %%
print(confusionmatrix)
# Out:
# [[19  0]
#  [ 0 11]]

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
if A_train.shape[1] == 2:
    plt.scatter(A_test[:, 0], A_test[:, 1], c=b_test, cmap=plt.cm.Paired, edgecolors='k', marker='o')
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')

    # Plot decision boundary
    h = .02
    x_min, x_max = A_test[:, 0].min() - 1, A_test[:, 0].max() + 1
    y_min, y_max = A_test[:, 1].min() - 1, A_test[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    plt.contourf(xx, yy, Z, cmap=plt.cm.Paired, alpha=0.8)

# %%
    plt.title('Logistic Regression Decision Boundary')
    plt.show()
