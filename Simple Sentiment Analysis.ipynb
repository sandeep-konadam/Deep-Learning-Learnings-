# %%
# !pip install transformers

# %%
import transformers
from transformers import pipeline
pipe_line=pipeline("sentiment-analysis")

# %%
data = ["Not bad", "Worst"]
pipe_line(data)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9995881915092468},
#  {'label': 'NEGATIVE', 'score': 0.9998016953468323}]
